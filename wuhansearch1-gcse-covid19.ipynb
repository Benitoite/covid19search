# %%
import requests
import pandas as pd
import sys, json
import json
import string
import datetime as dt
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
from config import csekey
import datetime as dt
import time as t

# %%
start_date = dt.date(2020, 1, 1)
end_date = dt.date(2021, 11, 3)
delta = dt.timedelta(days=1)
results = []
url = 'https://www.googleapis.com/customsearch/v1/siterestrict'

while start_date <= end_date:

    # Construct the sortby date
    date = str(start_date.year) + start_date.strftime('%m') + start_date.strftime('%d')
    params = { 'sort': 'date:r:'+date+':'+date, 'q': 'covid19', 'cx': 'e22950bd22e534ff4', 'key': csekey}

    # Poll the API service
    response = requests.get(url, params=params).json()
    hits=response['searchInformation']['totalResults']
    results.append([start_date,hits])
    print("Got " + date + " with " + str(hits) + " hits.")
    
    # Increment the sortby date
    start_date += delta

    # Throttle for a second
    t.sleep(1)
# Out:
# Got 20200101 with 0 hits.
# Got 20200102 with 0 hits.
# Got 20200103 with 0 hits.
# Got 20200104 with 0 hits.
# Got 20200105 with 0 hits.
# Got 20200106 with 0 hits.
# Got 20200107 with 0 hits.
# Got 20200108 with 0 hits.
# Got 20200109 with 1 hits.
# Got 20200110 with 0 hits.
# Got 20200111 with 0 hits.
# Got 20200112 with 0 hits.
# Got 20200113 with 0 hits.
# Got 20200114 with 0 hits.
# Got 20200115 with 0 hits.
# Got 20200116 with 0 hits.
# Got 20200117 with 0 hits.
# Got 20200118 with 0 hits.
# Got 20200119 with 0 hits.
# Got 20200120 with 0 hits.
# Got 20200121 with 0 hits.
# Got 20200122 with 0 hits.
# Got 20200123 with 0 hits.
# Got 20200124 with 0 hits.
# Got 20200125 with 0 hits.
# Got 20200126 with 0 hits.
# Got 20200127 with 0 hits.
# Got 20200128 with 0 hits.
# Got 20200129 with 0 hits.
# Got 20200130 with 1 hits.
# Got 20200131 with 0 hits.
# Got 20200201 with 1 hits.
# Got 20200202 with 0 hits.
# Got 20200203 with 0 hits.
# Got 20200204 with 0 hits.
# Got 20200205 with 0 hits.
# Got 20200206 with 0 hits.
# Got 20200207 with 0 hits.
# Got 20200208 with 0 hits.
# Got 20200209 with 1 hits.
# Got 20200210 with 0 hits.
# Got 20200211 with 0 hits.
# Got 20200212 with 0 hits.
# Got 20200213 with 0 hits.
# Got 20200214 with 0 hits.
# Got 20200215 with 0 hits.
# Got 20200216 with 0 hits.
# Got 20200217 with 0 hits.
# Got 20200218 with 0 hits.
# Got 20200219 with 0 hits.
# Got 20200220 with 0 hits.
# Got 20200221 with 0 hits.
# Got 20200222 with 0 hits.
# Got 20200223 with 0 hits.
# Got 20200224 with 1 hits.
# Got 20200225 with 0 hits.
# Got 20200226 with 0 hits.
# Got 20200227 with 0 hits.
# Got 20200228 with 1 hits.
# Got 20200229 with 1 hits.
# Got 20200301 with 0 hits.
# Got 20200302 with 1 hits.
# Got 20200303 with 0 hits.
# Got 20200304 with 3 hits.
# Got 20200305 with 2 hits.
# Got 20200306 with 5 hits.
# Got 20200307 with 1 hits.
# Got 20200308 with 0 hits.
# Got 20200309 with 0 hits.
# Got 20200310 with 2 hits.
# Got 20200311 with 1 hits.
# Got 20200312 with 8 hits.
# Got 20200313 with 0 hits.
# Got 20200314 with 0 hits.
# Got 20200315 with 1 hits.
# Got 20200316 with 1 hits.
# Got 20200317 with 1 hits.
# Got 20200318 with 2 hits.
# Got 20200319 with 2 hits.
# Got 20200320 with 2 hits.
# Got 20200321 with 0 hits.
# Got 20200322 with 0 hits.
# Got 20200323 with 4 hits.
# Got 20200324 with 0 hits.
# Got 20200325 with 0 hits.
# Got 20200326 with 1 hits.
# Got 20200327 with 1 hits.
# Got 20200328 with 1 hits.
# Got 20200329 with 1 hits.
# Got 20200330 with 3 hits.
# Got 20200331 with 0 hits.
# Got 20200401 with 1 hits.
# Got 20200402 with 0 hits.
# Got 20200403 with 1 hits.
# Got 20200404 with 1 hits.
# Got 20200405 with 0 hits.
# Got 20200406 with 1 hits.
# Got 20200407 with 5 hits.
# Got 20200408 with 0 hits.
# Got 20200409 with 1 hits.
# Got 20200410 with 1 hits.
# Got 20200411 with 0 hits.
# Got 20200412 with 0 hits.
# Got 20200413 with 2 hits.
# Got 20200414 with 0 hits.
# Got 20200415 with 1 hits.
# Got 20200416 with 4 hits.
# Got 20200417 with 0 hits.
# Got 20200418 with 1 hits.
# Got 20200419 with 0 hits.
# Got 20200420 with 2 hits.
# Got 20200421 with 1 hits.
# Got 20200422 with 1 hits.
# Got 20200423 with 4 hits.
# Got 20200424 with 2 hits.
# Got 20200425 with 1 hits.
# Got 20200426 with 0 hits.
# Got 20200427 with 1 hits.
# Got 20200428 with 2 hits.
# Got 20200429 with 1 hits.
# Got 20200430 with 2 hits.
# Got 20200501 with 1 hits.
# Got 20200502 with 1 hits.
# Got 20200503 with 0 hits.
# Got 20200504 with 0 hits.
# Got 20200505 with 0 hits.
# Got 20200506 with 0 hits.
# Got 20200507 with 2 hits.
# Got 20200508 with 1 hits.
# Got 20200509 with 0 hits.
# Got 20200510 with 0 hits.
# Got 20200511 with 1 hits.
# Got 20200512 with 0 hits.
# Got 20200513 with 2 hits.
# Got 20200514 with 2 hits.
# Got 20200515 with 1 hits.
# Got 20200516 with 0 hits.
# Got 20200517 with 2 hits.
# Got 20200518 with 0 hits.
# Got 20200519 with 1 hits.
# Got 20200520 with 2 hits.
# Got 20200521 with 0 hits.
# Got 20200522 with 1 hits.
# Got 20200523 with 1 hits.
# Got 20200524 with 0 hits.
# Got 20200525 with 0 hits.
# Got 20200526 with 1 hits.
# Got 20200527 with 2 hits.
# Got 20200528 with 1 hits.
# Got 20200529 with 0 hits.
# Got 20200530 with 1 hits.
# Got 20200531 with 0 hits.
# Got 20200601 with 0 hits.
# Got 20200602 with 1 hits.
# Got 20200603 with 0 hits.
# Got 20200604 with 0 hits.
# Got 20200605 with 0 hits.
# Got 20200606 with 1 hits.
# Got 20200607 with 0 hits.
# Got 20200608 with 1 hits.
# Got 20200609 with 2 hits.
# Got 20200610 with 0 hits.
# Got 20200611 with 1 hits.
# Got 20200612 with 0 hits.
# Got 20200613 with 0 hits.
# Got 20200614 with 1 hits.
# Got 20200615 with 2 hits.
# Got 20200616 with 0 hits.
# Got 20200617 with 3 hits.
# Got 20200618 with 0 hits.
# Got 20200619 with 0 hits.
# Got 20200620 with 0 hits.
# Got 20200621 with 1 hits.
# Got 20200622 with 1 hits.
# Got 20200623 with 1 hits.
# Got 20200624 with 0 hits.
# Got 20200625 with 1 hits.
# Got 20200626 with 0 hits.
# Got 20200627 with 0 hits.
# Got 20200628 with 1 hits.
# Got 20200629 with 1 hits.
# Got 20200630 with 1 hits.
# Got 20200701 with 1 hits.
# Got 20200702 with 1 hits.
# Got 20200703 with 0 hits.
# Got 20200704 with 0 hits.
# Got 20200705 with 1 hits.
# Got 20200706 with 0 hits.
# Got 20200707 with 1 hits.
# Got 20200708 with 0 hits.
# Got 20200709 with 0 hits.
# Got 20200710 with 0 hits.
# Got 20200711 with 0 hits.
# Got 20200712 with 0 hits.
# Got 20200713 with 0 hits.
# Got 20200714 with 1 hits.
# Got 20200715 with 1 hits.
# Got 20200716 with 1 hits.
# Got 20200717 with 0 hits.
# Got 20200718 with 0 hits.
# Got 20200719 with 0 hits.
# Got 20200720 with 1 hits.
# Got 20200721 with 0 hits.
# Got 20200722 with 1 hits.
# Got 20200723 with 0 hits.
# Got 20200724 with 1 hits.
# Got 20200725 with 0 hits.
# Got 20200726 with 0 hits.
# Got 20200727 with 1 hits.
# Got 20200728 with 0 hits.
# Got 20200729 with 0 hits.
# Got 20200730 with 0 hits.
# Got 20200731 with 1 hits.
# Got 20200801 with 0 hits.
# Got 20200802 with 0 hits.
# Got 20200803 with 0 hits.
# Got 20200804 with 0 hits.
# Got 20200805 with 0 hits.
# Got 20200806 with 0 hits.
# Got 20200807 with 0 hits.
# Got 20200808 with 0 hits.
# Got 20200809 with 1 hits.
# Got 20200810 with 1 hits.
# Got 20200811 with 1 hits.
# Got 20200812 with 0 hits.
# Got 20200813 with 1 hits.
# Got 20200814 with 1 hits.
# Got 20200815 with 0 hits.
# Got 20200816 with 0 hits.
# Got 20200817 with 1 hits.
# Got 20200818 with 2 hits.
# Got 20200819 with 0 hits.
# Got 20200820 with 0 hits.
# Got 20200821 with 0 hits.
# Got 20200822 with 1 hits.
# Got 20200823 with 0 hits.
# Got 20200824 with 3 hits.
# Got 20200825 with 2 hits.
# Got 20200826 with 1 hits.
# Got 20200827 with 1 hits.
# Got 20200828 with 0 hits.
# Got 20200829 with 0 hits.
# Got 20200830 with 1 hits.
# Got 20200831 with 0 hits.
# Got 20200901 with 0 hits.
# Got 20200902 with 0 hits.
# Got 20200903 with 2 hits.
# Got 20200904 with 0 hits.
# Got 20200905 with 0 hits.
# Got 20200906 with 0 hits.
# Got 20200907 with 0 hits.
# Got 20200908 with 1 hits.
# Got 20200909 with 0 hits.
# Got 20200910 with 0 hits.
# Got 20200911 with 0 hits.
# Got 20200912 with 1 hits.
# Got 20210920 with 10 hits.
# Got 20210921 with 8 hits.
# Got 20210922 with 143000000 hits.
# Got 20210923 with 10 hits.
# Got 20210924 with 147000000 hits.
# Got 20210925 with 2 hits.
# Got 20210926 with 2 hits.
# Got 20210927 with 148000000 hits.
# Got 20210928 with 139000000 hits.
# Got 20210929 with 140000000 hits.
# Got 20210930 with 137000000 hits.
# Got 20211001 with 148000000 hits.
# Got 20211002 with 146000000 hits.
# Got 20211003 with 147000000 hits.
# Got 20211004 with 139000000 hits.
# Got 20211005 with 0 hits.
# Got 20211006 with 0 hits.
# Got 20211007 with 0 hits.
# Got 20211008 with 0 hits.
# Got 20211009 with 0 hits.
# Got 20211010 with 0 hits.
# Got 20211011 with 0 hits.
# Got 20211012 with 0 hits.
# Got 20211013 with 0 hits.
# Got 20211014 with 0 hits.
# Got 20211015 with 0 hits.
# Got 20211016 with 0 hits.
# Got 20211017 with 0 hits.
# Got 20211018 with 0 hits.
# Got 20211019 with 0 hits.
# Got 20211020 with 0 hits.
# Got 20211021 with 0 hits.
# Got 20211022 with 0 hits.
# Got 20211023 with 0 hits.
# Got 20211024 with 0 hits.
# Got 20211025 with 0 hits.
# Got 20211026 with 0 hits.
# Got 20211027 with 0 hits.
# Got 20211028 with 0 hits.
# Got 20211029 with 0 hits.
# Got 20211030 with 0 hits.
# Got 20211031 with 0 hits.
# Got 20211101 with 0 hits.
# Got 20211102 with 0 hits.
# Got 20211103 with 0 hits.

# %%
response
# Out:
# {'kind': 'customsearch#search',
#  'url': {'type': 'application/json',
#   'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&relatedSite={relatedSite?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json'},
#  'queries': {'request': [{'title': 'Google Custom Search - covid19',
#     'searchTerms': 'covid19',
#     'count': 10,
#     'startIndex': 1,
#     'inputEncoding': 'utf8',
#     'outputEncoding': 'utf8',
#     'safe': 'off',
#     'cx': 'e22950bd22e534ff4',
#     'sort': 'date:r:20211103:20211103'}]},
#  'searchInformation': {'searchTime': 0.47747,
#   'formattedSearchTime': '0.48',
#   'totalResults': '0',
#   'formattedTotalResults': '0'},
#  'spelling': {'correctedQuery': 'covid 19',
#   'htmlCorrectedQuery': '<b><i>covid 19</i></b>'}}

# %%
df = pd.DataFrame(results, columns=["date","totalResults"])

# Decode vaules above 10
for i,row in df.iterrows():
    if int(row[1]) > 100:
        df.iloc[i][1] = int(int(row[1])//1000000-124)

# Drop 0 result rows
for i,row in df.iterrows():
    if int(row[1]) == 0:
        df.drop(i,inplace=True)

# %%
df.tail(44)
# Out:
#            date totalResults
# 599  2021-08-22            1
# 600  2021-08-23           18
# 601  2021-08-24           10
# 602  2021-08-25           17
# 603  2021-08-26           24
# 604  2021-08-27           25
# 605  2021-08-28            3
# 606  2021-08-29            4
# 607  2021-08-30           20
# 608  2021-08-31            8
# 609  2021-09-01           11
# 610  2021-09-02           10
# 611  2021-09-03           16
# 612  2021-09-04            2
# 613  2021-09-05            4
# 614  2021-09-06            6
# 615  2021-09-07           10
# 616  2021-09-08           18
# 617  2021-09-09           16
# 618  2021-09-10           17
# 619  2021-09-11            2
# 620  2021-09-12            2
# 621  2021-09-13           14
# 622  2021-09-14           19
# 623  2021-09-15           21
# 624  2021-09-16           20
# 625  2021-09-17           17
# 626  2021-09-18            5
# 627  2021-09-19            7
# 628  2021-09-20           10
# 629  2021-09-21            8
# 630  2021-09-22           19
# 631  2021-09-23           10
# 632  2021-09-24           23
# 633  2021-09-25            2
# 634  2021-09-26            2
# 635  2021-09-27           24
# 636  2021-09-28           15
# 637  2021-09-29           16
# 638  2021-09-30           13
# 639  2021-10-01           24
# 640  2021-10-02           22
# 641  2021-10-03           23
# 642  2021-10-04           15

# %%
df.reset_index(drop=True).set_index('date')
# Out:
#            totalResults
# date
# 2020-01-09            1
# 2020-01-30            1
# 2020-02-01            1
# 2020-02-09            1
# 2020-02-24            1
# ...                 ...
# 2021-09-30           13
# 2021-10-01           24
# 2021-10-02           22
# 2021-10-03           23
# 2021-10-04           15
#
# [413 rows x 1 columns]

# %%
df.to_csv('google-covid19-list.csv', index=False)

# %%
df.iloc[0:]['date']
# Out:
# 8      2020-01-09
# 29     2020-01-30
# 31     2020-02-01
# 39     2020-02-09
# 54     2020-02-24
#           ...
# 638    2021-09-30
# 639    2021-10-01
# 640    2021-10-02
# 641    2021-10-03
# 642    2021-10-04
# Name: date, Length: 413, dtype: object

# %%
x = df.iloc[0:]['date']
y = df.iloc[0:]['totalResults'].astype('int')

fig= plt.figure(figsize=(16, 8), dpi=400,facecolor='lavender')
tfont = {'fontname':'Microsoft JhengHei'}
plt.gca().xaxis.set_minor_formatter(mdates.DateFormatter('%B'))
plt.gca().xaxis.set_minor_locator(mdates.MonthLocator())
plt.gca().tick_params(axis="x", which="both", rotation=67)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y/%b'))
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.scatter(x,y,s=y*50,marker='+',color='k')
plt.gca().grid(which='major', color='r', linestyle='-.', linewidth=.3, alpha=1)  
plt.gca().grid(which='minor', color='b', linestyle='-.', linewidth=.2,alpha=.7)
plt.ylim(top=23,bottom=0)
plt.xlim(left=pd.to_datetime('20200101T00:00:00Z'))
plt.title('Items Found with "covid19" on news.google.com/* by date',**tfont,size=16)
plt.show()
plt.close()
